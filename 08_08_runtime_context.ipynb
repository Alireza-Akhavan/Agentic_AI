# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "آبی"
    least_favourite_colour: str = "زرد"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="رنگ مورد علاقه من چیه؟")]},
    context=ColourContext()
)

# %%
print(response["messages"][-1].content)
# Out:
# نمی‌تونم دقیقاً بدون هیچ اطلاعاتی رنگ محبوب شما را حدس بزنم. اگر بخواهی، می‌تونم با یک بازی کوتاه حدس بزنم یا فقط چند رنگ محبوب و پرطرفدار بهت پیشنهاد کنم. دوست داری کدوم رو انجام بدیم؟
#
# اگر می‌خواهی همین حالا حدس بزنم، چند تا سوال ساده جواب بده:
# 1) دوست داری رنگ‌های گرم (قرمز، نارنجی، زرد) یا سرد (آبی، سبز، بنفش) را ترجیح بدهی؟
# 2) رنگ روشن دوست داری یا تيره؟
# 3) دوست داری رنگی باشد که با اکثر لباس‌ها ست شود یا رنگی که بیشتر به چشم بیاید و جلب توجه کند؟
# 4) کدام حس را می‌خواهی منتقل کند: آرامش یا انرژی/ هیجان؟
# 5) به کدام الهام از طبیعت گرایش داری؟ آبی آسمان و دریای سرد، سبز جنگل و برگ، یا خاکی و خنثی؟
#
# با پاسخ دادن به این سوال‌ها، من یک رنگ حدسی بهت معرفی می‌کنم. یا اگر فقط چند رنگ پیشنهادی می‌خواهی، بگو تا همین الآن چند گزینه خوب بدهمت.

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="رنگ مورد علاقه ام چیه؟")]},
    context=ColourContext()
)

print(response["messages"][-1].content)
# Out:
# C:\Users\Alireza\AppData\Roaming\Python\Python312\site-packages\pydantic\functional_validators.py:835: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='زرد'), input_type=ColourContext])
#   function=lambda v, h: h(v), schema=original_schema
# C:\Users\Alireza\AppData\Roaming\Python\Python312\site-packages\pydantic\main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='زرد'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# رنگ مورد علاقه‌ت آبی است.
#
# اگر دوست داری، می‌تونیم رنگ‌های مشابه یا ترکیب‌های رنگی با آبی را هم بررسی کنیم.

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="رنگ مورد علاقه ام چیه؟")]},
    context=ColourContext(favourite_colour="green")
)

print(response["messages"][-1].content)
# Out:
# C:\Users\Alireza\AppData\Roaming\Python\Python312\site-packages\pydantic\functional_validators.py:835: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='زرد'), input_type=ColourContext])
#   function=lambda v, h: h(v), schema=original_schema
# C:\Users\Alireza\AppData\Roaming\Python\Python312\site-packages\pydantic\main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='زرد'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# رنگ مورد علاقه‌تان سبز است. می‌خواهید رنگ کم‌دوست‌تان را هم بدانیم؟ اگر بگویید، می‌توانم آن را هم بیاورم.
